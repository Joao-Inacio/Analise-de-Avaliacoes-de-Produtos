# %% [markdown]
# # Análise Exploratória de Dados

# %% [markdown]
# ## Transformando CSV para JSON

# %%
# Módulos
from preprocessamento import csv_para_json, adicionar_dados

# %%
# Importando arquivo
arquivo = r'C:\Analise-de-Avaliacoes-de-Produtos\dados\ml_scrape_final.csv'
dados = csv_para_json(arquivo)
dados
# Out:
# [{'Pesquisa': 'smartphone',
#   'Titulo': 'Smartphone Samsung Galaxy A14 Dual 6.6 128gb Preto 4gb Ram',
#   'Link': 'https://produto.mercadolivre.com.br/MLB-3315181641-smartphone-samsung-galaxy-a14-dual-66-128gb-preto-4gb-ram-_JM#position=46&search_layout=stack&type=item&tracking_id=4703b69b-1b0f-4cc2-b281-a641f81b3281',
#   'Comentario': 'A foto fica amarelada quando eu vou fotografar com celular.'},
#  {'Pesquisa': 'smartphone',
#   'Titulo': 'Smartphone Samsung Galaxy A14 Dual 6.6 128gb Preto 4gb Ram',
#   'Link': 'https://produto.mercadolivre.com.br/MLB-3315181641-smartphone-samsung-galaxy-a14-dual-66-128gb-preto-4gb-ram-_JM#position=46&search_layout=stack&type=item&tracking_id=4703b69b-1b0f-4cc2-b281-a641f81b3281',
#   'Comentario': '👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼.'},
#  {'Pesquisa': 'smartphone',
#   'Titulo': 'Smartphone Samsung Galaxy A14 Dual 6.6 128gb Preto 4gb Ram',
# ...

# %%
# Adicionando dados no mongoDB
bd_nome = 'dbreviews'
collection_nome = 'reviews'
adicionar_dados(dados, bd_nome, collection_nome)
# Out:
# Dados inseridos com sucesso em dbreviews.reviews!
